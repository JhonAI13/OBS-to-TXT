# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\jonat\Documents\GitHub\OBS-to-TXT\dflimpo.csv")
df.describe()
# Out:
#        Contagem de Palavras       Links  Palavras/Link   cont_tags  \
# count            731.000000  731.000000     731.000000  731.000000
# mean             145.772914    2.755130       1.973697    0.748290
# std              332.708215    7.579277       3.711640    0.607809
# min                0.000000    0.000000       0.001787    0.000000
# 25%               34.000000    0.000000       0.520107    0.000000
# 50%               68.000000    1.000000       1.164671    1.000000
# 75%              157.000000    3.000000       2.122837    1.000000
# max             4414.000000  150.000000      67.750000    2.000000
#
#        quão_escondido
# count      731.000000
# mean         3.359781
# std          1.207498
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000

# %%
plt.hist(df['Contagem de Palavras'])
# Out:
# (array([  9.,   0.,   9.,   0., 189.,   0., 205.,   0., 141., 178.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Links'])
# Out:
# (array([703.,  23.,   2.,   1.,   1.,   0.,   0.,   0.,   0.,   1.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <BarContainer object of 10 artists>)
