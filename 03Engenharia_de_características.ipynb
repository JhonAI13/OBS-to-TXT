# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\jonat\Documents\GitHub\OBS-to-TXT\dflimpo.csv")
df
# Out:
#       Nome da Nota Data da Última Modificação Data da Nota             Tags  \
# 0             ,pop                 2024-11-13   2024-11-13       ['Python']
# 1    Discretização                 2024-10-23   2024-10-23  ['DataAnalyst']
# 2              EDA                 2024-12-03   2024-12-03  ['DataAnalyst']
# 3          Indução                 2024-10-29   2024-10-29  ['DataAnalyst']
# 4          o'clock                 2024-11-22   2024-11-22         ['Word']
# ..             ...                        ...          ...              ...
# 726    Nota diaria                 2023-09-27          NaN               []
# 727        Pessoas                 2023-09-27          NaN               []
# 728           pret                 2024-09-19          NaN               []
# 729          Sites                 2024-04-28   2024-04-28               []
# 730          Vídeo                 2024-04-28   2024-04-28               []
#
#      Contagem de Palavras  Links                       Caminho da Nota  \
# 0                     108      0                               ,pop.md
# 1                      28      0                      Discretização.md
# 2                     158      8                                EDA.md
# 3                     132      6                            Indução.md
# 4                      26      2                            o'clock.md
# ..                    ...    ...                                   ...
# 726                     2      0  99 - Recursos\Modelos\Nota diaria.md
# 727                    48      0      99 - Recursos\Modelos\Pessoas.md
# 728                    30      0         99 - Recursos\Modelos\pret.md
# 729                     7      0        99 - Recursos\Modelos\Sites.md
# 730                     8      0        99 - Recursos\Modelos\Vídeo.md
#
#      Palavras/Link  cont_tags  quão_escondido
# 0         0.465594          1               0
# 1         1.042002          1               0
# 2         2.696296          1               0
# 3         2.250000          1               0
# 4         2.645089          1               0
# ..             ...        ...             ...
# 726       1.258266          0               2
# 727       0.827525          0               2
# 728       1.021448          0               2
# 729       1.241287          0               2
# 730       1.236819          0               2
#
# [731 rows x 10 columns]

# %%
# Aplicando a função na coluna "Contagem de Palavras"
df['Palavras/Link'] = df['Contagem de Palavras'].rank(method='average', ascending=False)/df['Links'].rank(method='average', ascending=False)
df.head(10)
# Out:
#              Nome da Nota Data da Última Modificação Data da Nota  \
# 0                    ,pop                 2024-11-13   2024-11-13
# 1           Discretização                 2024-10-23   2024-10-23
# 2                     EDA                 2024-12-03   2024-12-03
# 3                 Indução                 2024-10-29   2024-10-29
# 4                 o'clock                 2024-11-22   2024-11-22
# 5  quantidade de palavras                 2024-11-28          NaN
# 6              Sem título                 2024-11-22          NaN
# 7               Tripleten                 2024-10-29   2024-10-29
# 8               vxcvx.gif                 2024-12-10          NaN
# 9                   Ações                 2024-07-17          NaN
#
#               Tags  Contagem de Palavras  Links            Caminho da Nota  \
# 0       ['Python']                   108      0                    ,pop.md
# 1  ['DataAnalyst']                    28      0           Discretização.md
# 2  ['DataAnalyst']                   158      8                     EDA.md
# 3  ['DataAnalyst']                   132      6                 Indução.md
# 4         ['Word']                    26      2                 o'clock.md
# 5               []                   592      0  quantidade de palavras.md
# 6               []                     0      0              Sem título.md
# 7  ['DataAnalyst']                    97      0               Tripleten.md
# 8               []                     0      0               vxcvx.gif.md
# 9               []                     0      0            .trash\Ações.md
#
#    Palavras/Link  cont_tags  quão_escondido
# 0       0.465594          1               0
# 1       1.042002          1               0
# 2       2.696296          1               0
# 3       2.250000          1               0
# 4       2.645089          1               0
# 5       0.026810          0               0
# 6       1.284182          0               0
# 7       0.501340          1               0
# 8       1.284182          0               0
# 9       1.284182          0               1

# %%
df.sort_values("Palavras/Link").head(10)
# Out:
#                                           Nome da Nota  \
# 627                                          progeto 3
# 24                                          pythonloco
# 18                                300 palavras basicas
# 17                      O voto não é o que você pensa.
# 244                                        correlações
# 688  From Paper to Bionics Origami's Incredible Imp...
# 255                            Problemas de Morfologia
# 671  87 DICAS OBSIDIAN Do Iniciante ao Avançado  Tu...
# 253            Perceptron e Aprendizado Supervisionado
# 5                               quantidade de palavras
#
#     Data da Última Modificação Data da Nota             Tags  \
# 627                 2024-12-15          NaN               []
# 24                  2024-11-19          NaN               []
# 18                  2024-12-06          NaN               []
# 17                  2024-09-19          NaN               []
# 244                 2024-10-04          NaN               []
# 688                 2024-04-30   2024-04-28               []
# 255                 2024-10-04   2024-10-04  ['DataAnalyst']
# 671                 2024-12-30   2024-04-28  ['Aprendizado']
# 253                 2024-10-08   2024-10-08  ['DataAnalyst']
# 5                   2024-11-28          NaN               []
#
#      Contagem de Palavras  Links  \
# 627                  4414      0
# 24                   4296      0
# 18                   3738      0
# 17                   2732      0
# 244                  1544      0
# 688                  1445      0
# 255                  1102      0
# 671                   976      0
# 253                   667      0
# 5                     592      0
#
#                                        Caminho da Nota  Palavras/Link  \
# 627  01 - Progetos\zData Analyst\Tripleten\progeto ...       0.001787
# 24                    01 - Progetos\Anki\pythonloco.md       0.003575
# 18          01 - Progetos\Anki\300 palavras basicas.md       0.005362
# 17     01 - Progetos\O voto não é o que você pensa..md       0.007149
# 244  01 - Progetos\zData Analyst\Livros\correlações.md       0.012511
# 688  02 - Referencias\Videos\From Paper to Bionics ...       0.014298
# 255  01 - Progetos\zData Analyst\PLN\Problemas de M...       0.017873
# 671  02 - Referencias\Videos\87 DICAS OBSIDIAN Do I...       0.019660
# 253  01 - Progetos\zData Analyst\PLN\Perceptron e A...       0.025022
# 5                            quantidade de palavras.md       0.026810
#
#      cont_tags  quão_escondido
# 627          0               3
# 24           0               2
# 18           0               2
# 17           0               1
# 244          0               3
# 688          0               2
# 255          1               3
# 671          1               2
# 253          1               3
# 5            0               0

# %%
import ast
df['cont_tags'] = df['Tags'].apply(lambda x: ast.literal_eval(x)).apply(len)
df
# Out:
#       Nome da Nota Data da Última Modificação Data da Nota             Tags  \
# 0             ,pop                 2024-11-13   2024-11-13       ['Python']
# 1    Discretização                 2024-10-23   2024-10-23  ['DataAnalyst']
# 2              EDA                 2024-12-03   2024-12-03  ['DataAnalyst']
# 3          Indução                 2024-10-29   2024-10-29  ['DataAnalyst']
# 4          o'clock                 2024-11-22   2024-11-22         ['Word']
# ..             ...                        ...          ...              ...
# 726    Nota diaria                 2023-09-27          NaN               []
# 727        Pessoas                 2023-09-27          NaN               []
# 728           pret                 2024-09-19          NaN               []
# 729          Sites                 2024-04-28   2024-04-28               []
# 730          Vídeo                 2024-04-28   2024-04-28               []
#
#      Contagem de Palavras  Links                       Caminho da Nota  \
# 0                     108      0                               ,pop.md
# 1                      28      0                      Discretização.md
# 2                     158      8                                EDA.md
# 3                     132      6                            Indução.md
# 4                      26      2                            o'clock.md
# ..                    ...    ...                                   ...
# 726                     2      0  99 - Recursos\Modelos\Nota diaria.md
# 727                    48      0      99 - Recursos\Modelos\Pessoas.md
# 728                    30      0         99 - Recursos\Modelos\pret.md
# 729                     7      0        99 - Recursos\Modelos\Sites.md
# 730                     8      0        99 - Recursos\Modelos\Vídeo.md
#
#      Palavras/Link  cont_tags  quão_escondido
# 0         0.465594          1               0
# 1         1.042002          1               0
# 2         2.696296          1               0
# 3         2.250000          1               0
# 4         2.645089          1               0
# ..             ...        ...             ...
# 726       1.258266          0               2
# 727       0.827525          0               2
# 728       1.021448          0               2
# 729       1.241287          0               2
# 730       1.236819          0               2
#
# [731 rows x 10 columns]

# %%
df['quão_escondido'] = df['Caminho da Nota'].str.count(r"\\")
df
# Out:
#       Nome da Nota Data da Última Modificação Data da Nota             Tags  \
# 0             ,pop                 2024-11-13   2024-11-13       ['Python']
# 1    Discretização                 2024-10-23   2024-10-23  ['DataAnalyst']
# 2              EDA                 2024-12-03   2024-12-03  ['DataAnalyst']
# 3          Indução                 2024-10-29   2024-10-29  ['DataAnalyst']
# 4          o'clock                 2024-11-22   2024-11-22         ['Word']
# ..             ...                        ...          ...              ...
# 726    Nota diaria                 2023-09-27          NaN               []
# 727        Pessoas                 2023-09-27          NaN               []
# 728           pret                 2024-09-19          NaN               []
# 729          Sites                 2024-04-28   2024-04-28               []
# 730          Vídeo                 2024-04-28   2024-04-28               []
#
#      Contagem de Palavras  Links                       Caminho da Nota  \
# 0                     108      0                               ,pop.md
# 1                      28      0                      Discretização.md
# 2                     158      8                                EDA.md
# 3                     132      6                            Indução.md
# 4                      26      2                            o'clock.md
# ..                    ...    ...                                   ...
# 726                     2      0  99 - Recursos\Modelos\Nota diaria.md
# 727                    48      0      99 - Recursos\Modelos\Pessoas.md
# 728                    30      0         99 - Recursos\Modelos\pret.md
# 729                     7      0        99 - Recursos\Modelos\Sites.md
# 730                     8      0        99 - Recursos\Modelos\Vídeo.md
#
#      Palavras/Link  cont_tags  quão_escondido
# 0         0.465594          1               0
# 1         1.042002          1               0
# 2         2.696296          1               0
# 3         2.250000          1               0
# 4         2.645089          1               0
# ..             ...        ...             ...
# 726       1.258266          0               2
# 727       0.827525          0               2
# 728       1.021448          0               2
# 729       1.241287          0               2
# 730       1.236819          0               2
#
# [731 rows x 10 columns]

# %%
df.to_csv('dflimpo.csv', index=False, encoding='utf-8')
