# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\jonat\Documents\GitHub\OBS-to-TXT\dflimpo.csv")
df
# Out:
#                       Nome da Nota Data da Última Modificação Data da Nota  \
# 0                             ,pop                 2024-11-13   2024-11-13
# 1                    Discretização                 2024-10-23   2024-10-23
# 2                              EDA                 2024-12-03   2024-12-03
# 3                          Indução                 2024-10-29   2024-10-29
# 4     O descobrimento de Portugal.                 2024-12-31   2024-12-31
# ...                            ...                        ...          ...
# 1196                       Pessoas                 2023-09-27          NaN
# 1197                          pret                 2024-09-19          NaN
# 1198                         Sites                 2025-04-07          NaN
# 1199                         Vídeo                 2025-07-12          NaN
# 1200              Reset LaTeX Size                 2025-07-01          NaN
#
#                  Tags  Contagem de Palavras  Links  \
# 0          ['Python']                   108      0
# 1     ['DataAnalyst']                    28      0
# 2     ['DataAnalyst']                   158      8
# 3     ['DataAnalyst']                   132      6
# 4                  []                   155      0
# ...               ...                   ...    ...
# 1196               []                    48      0
# 1197               []                    30      0
# 1198               []                     5      0
# 1199               []                     5      0
# 1200               []                   130      0
#
#                                         Caminho da Nota
# 0                                               ,pop.md
# 1                                      Discretização.md
# 2                                                EDA.md
# 3                                            Indução.md
# 4                       O descobrimento de Portugal..md
# ...                                                 ...
# 1196                   99 - Recursos\Modelos\Pessoas.md
# 1197                      99 - Recursos\Modelos\pret.md
# 1198                     99 - Recursos\Modelos\Sites.md
# 1199                     99 - Recursos\Modelos\Vídeo.md
# 1200  Excalidraw\Scripts\Downloaded\Reset LaTeX Size.md
#
# [1201 rows x 7 columns]

# %%
# Aplicando a função na coluna "Contagem de Palavras"
df['Palavras/Link'] = df['Contagem de Palavras'].rank(method='average', ascending=False)/df['Links'].rank(method='average', ascending=False)
df.head(10)
# Out:
#                    Nome da Nota Data da Última Modificação Data da Nota  \
# 0                          ,pop                 2024-11-13   2024-11-13
# 1                 Discretização                 2024-10-23   2024-10-23
# 2                           EDA                 2024-12-03   2024-12-03
# 3                       Indução                 2024-10-29   2024-10-29
# 4  O descobrimento de Portugal.                 2024-12-31   2024-12-31
# 5                       o'clock                 2024-11-22   2024-11-22
# 6        quantidade de palavras                 2024-11-28          NaN
# 7                  Sem título 1                 2025-08-06          NaN
# 8                  Sem título 2                 2025-09-09          NaN
# 9                  Sem título 3                 2025-09-18          NaN
#
#               Tags  Contagem de Palavras  Links  \
# 0       ['Python']                   108      0
# 1  ['DataAnalyst']                    28      0
# 2  ['DataAnalyst']                   158      8
# 3  ['DataAnalyst']                   132      6
# 4               []                   155      0
# 5         ['Word']                    26      2
# 6               []                   592      0
# 7               []                   196      0
# 8               []                    22      0
# 9               []                     0      0
#
#                    Caminho da Nota  Palavras/Link
# 0                          ,pop.md       0.548165
# 1                 Discretização.md       1.093463
# 2                           EDA.md       4.159091
# 3                       Indução.md       3.446721
# 4  O descobrimento de Portugal..md       0.426606
# 5                       o'clock.md       3.424779
# 6        quantidade de palavras.md       0.080275
# 7                  Sem título 1.md       0.344610
# 8                  Sem título 2.md       1.155390
# 9                  Sem título 3.md       1.354931

# %%
df.sort_values("Palavras/Link").head(10)
# Out:
#              Nome da Nota Data da Última Modificação Data da Nota  \
# 397             99freelas                 2025-07-10   2025-07-10
# 1187              Sumário                 2025-05-02          NaN
# 481                 Vagas                 2025-05-08          NaN
# 1188          001 Sumário                 2025-05-02          NaN
# 1011         Tudo que sei                 2025-06-04          NaN
# 1189          001 Sumário                 2025-05-02          NaN
# 1192          001 Sumário                 2025-05-02          NaN
# 1055   Cálculo.excalidraw                 2025-07-01          NaN
# 982                coorte                 2025-03-13          NaN
# 468   Funil real de vagas                 2025-05-20   2025-04-30
#
#                   Tags  Contagem de Palavras  Links  \
# 397                 []                376340      0
# 1187                []                 41088      0
# 481                 []                 37477      0
# 1188                []                 16128      0
# 1011                []                 13612      0
# 1189                []                 12220      0
# 1192                []                 10221      0
# 1055  ['[excalidraw]']                 15478      1
# 982                 []                  8275      0
# 468                 []                  6041      0
#
#                                         Caminho da Nota  Palavras/Link
# 397     01 - Progetos\zData Analyst\Frella\99freelas.md       0.001147
# 1187                     04 - Arquivo\Livros\Sumário.md       0.002294
# 481       01 - Progetos\zData Analyst\Linkedln\Vagas.md       0.003440
# 1188     04 - Arquivo\Livros\Estatística\001 Sumário.md       0.004587
# 1011  01 - Progetos\zData Analyst\Tripleten\Sprints\...       0.006881
# 1189  04 - Arquivo\Livros\Estatística\DA\001 Sumário.md       0.008028
# 1192              04 - Arquivo\Livros\PC\001 Sumário.md       0.009174
# 1055  02 - Referencias\Livros\Cálculo\Cálculo.excali...       0.011429
# 982   01 - Progetos\zData Analyst\Tripleten\Aulas\co...       0.011468
# 468   01 - Progetos\zData Analyst\Linkedln\Funil rea...       0.016055

# %%
import ast
df['cont_tags'] = df['Tags'].apply(lambda x: ast.literal_eval(x)).apply(len)
df
# Out:
#                       Nome da Nota Data da Última Modificação Data da Nota  \
# 0                             ,pop                 2024-11-13   2024-11-13
# 1                    Discretização                 2024-10-23   2024-10-23
# 2                              EDA                 2024-12-03   2024-12-03
# 3                          Indução                 2024-10-29   2024-10-29
# 4     O descobrimento de Portugal.                 2024-12-31   2024-12-31
# ...                            ...                        ...          ...
# 1196                       Pessoas                 2023-09-27          NaN
# 1197                          pret                 2024-09-19          NaN
# 1198                         Sites                 2025-04-07          NaN
# 1199                         Vídeo                 2025-07-12          NaN
# 1200              Reset LaTeX Size                 2025-07-01          NaN
#
#                  Tags  Contagem de Palavras  Links  \
# 0          ['Python']                   108      0
# 1     ['DataAnalyst']                    28      0
# 2     ['DataAnalyst']                   158      8
# 3     ['DataAnalyst']                   132      6
# 4                  []                   155      0
# ...               ...                   ...    ...
# 1196               []                    48      0
# 1197               []                    30      0
# 1198               []                     5      0
# 1199               []                     5      0
# 1200               []                   130      0
#
#                                         Caminho da Nota  Palavras/Link  \
# 0                                               ,pop.md       0.548165
# 1                                      Discretização.md       1.093463
# 2                                                EDA.md       4.159091
# 3                                            Indução.md       3.446721
# 4                       O descobrimento de Portugal..md       0.426606
# ...                                                 ...            ...
# 1196                   99 - Recursos\Modelos\Pessoas.md       0.881881
# 1197                      99 - Recursos\Modelos\pret.md       1.071101
# 1198                     99 - Recursos\Modelos\Sites.md       1.317087
# 1199                     99 - Recursos\Modelos\Vídeo.md       1.317087
# 1200  Excalidraw\Scripts\Downloaded\Reset LaTeX Size.md       0.489106
#
#       cont_tags
# 0             1
# 1             1
# 2             1
# 3             1
# 4             0
# ...         ...
# 1196          0
# 1197          0
# 1198          0
# 1199          0
# 1200          0
#
# [1201 rows x 9 columns]

# %%
df['quão_escondido'] = df['Caminho da Nota'].str.count(r"\\")
df
# Out:
#                       Nome da Nota Data da Última Modificação Data da Nota  \
# 0                             ,pop                 2024-11-13   2024-11-13
# 1                    Discretização                 2024-10-23   2024-10-23
# 2                              EDA                 2024-12-03   2024-12-03
# 3                          Indução                 2024-10-29   2024-10-29
# 4     O descobrimento de Portugal.                 2024-12-31   2024-12-31
# ...                            ...                        ...          ...
# 1196                       Pessoas                 2023-09-27          NaN
# 1197                          pret                 2024-09-19          NaN
# 1198                         Sites                 2025-04-07          NaN
# 1199                         Vídeo                 2025-07-12          NaN
# 1200              Reset LaTeX Size                 2025-07-01          NaN
#
#                  Tags  Contagem de Palavras  Links  \
# 0          ['Python']                   108      0
# 1     ['DataAnalyst']                    28      0
# 2     ['DataAnalyst']                   158      8
# 3     ['DataAnalyst']                   132      6
# 4                  []                   155      0
# ...               ...                   ...    ...
# 1196               []                    48      0
# 1197               []                    30      0
# 1198               []                     5      0
# 1199               []                     5      0
# 1200               []                   130      0
#
#                                         Caminho da Nota  Palavras/Link  \
# 0                                               ,pop.md       0.548165
# 1                                      Discretização.md       1.093463
# 2                                                EDA.md       4.159091
# 3                                            Indução.md       3.446721
# 4                       O descobrimento de Portugal..md       0.426606
# ...                                                 ...            ...
# 1196                   99 - Recursos\Modelos\Pessoas.md       0.881881
# 1197                      99 - Recursos\Modelos\pret.md       1.071101
# 1198                     99 - Recursos\Modelos\Sites.md       1.317087
# 1199                     99 - Recursos\Modelos\Vídeo.md       1.317087
# 1200  Excalidraw\Scripts\Downloaded\Reset LaTeX Size.md       0.489106
#
#       cont_tags  quão_escondido
# 0             1               0
# 1             1               0
# 2             1               0
# 3             1               0
# 4             0               0
# ...         ...             ...
# 1196          0               2
# 1197          0               2
# 1198          0               2
# 1199          0               2
# 1200          0               3
#
# [1201 rows x 10 columns]

# %%
df.to_csv('dflimpo.csv', index=False, encoding='utf-8')
